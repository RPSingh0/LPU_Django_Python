# %% [markdown]
# # Q1.  From this given string: s = "Hey i am from New Delhi". Find out: length of string, convert this to list using split operation.

# %%
s = input("Enter a string:")
print(s.__len__())
s = s.split(" ")
print(s)
# Out:
# 23
# ['Hey', 'i', 'am', 'from', 'New', 'Delhi']

# %% [markdown]
# # Q2.  Given string s = "name is rahul". Write code to give following o/p.
# - "Name is rahul"
# -  "Rame Is Rahul"
# -  "NAME IS RAHUL"

# %%
s = "name is rahul"
print(s.capitalize())
print(s.replace("n","R").title())
print(s.upper())
# Out:
# Name is rahul
# Rame Is Rahul
# NAME IS RAHUL

# %% [markdown]
# # Q3. Using length and breadth as input find out area and perimeter of a given rectangle.

# %% [markdown]
# ## #taking length as 4
# ## #taking bredth as 5

# %%
length, bredth = list(map(float,input("Enter length and bredth").split(" ")))
print("Area =", length*bredth)
print("Perimeter =", 2*(length*bredth))
# Out:
# Area = 20.0
# Perimeter = 40.0

# %% [markdown]
# # Q4. Using diameter as input find out circumference and area of a circle.

# %% [markdown]
# ## #Taking diameter as 7

# %%
diameter = float(input("Enter the diameter:"))
print("Circumference =", 2*(3.14*(diameter/2)))
print("Area =", 3.14*(diameter/2)**2)
# Out:
# Circumference = 21.98
# Area = 38.465

# %% [markdown]
# # Q5. Write a program to compute roots of a quadratic equation when coefficients a, b and c are known(entered by user).

# %% [markdown]
# ## #Taking a=5 b=4 c=1

# %%
import cmath
a, b, c = [float(x) for x in input("Enter quadratic coefficients ax^2 + bx + c = 0").split(" ")]
discriminent = b**2 - 4*a*c
print(f"The roots are {(-b+cmath.sqrt(discriminent))/2*a} and {(-b-cmath.sqrt(discriminent))/2*a}")
# Out:
# The roots are (-10+5j) and (-10-5j)

# %% [markdown]
# # Q6. Find volume of a sphere using radius as input.

# %% [markdown]
# ## #Taking radius as 23

# %%
radius = float(input("Enter the radius of sphere:"))
print("Volume =",round((4/3)*3.14*(radius**3),2))
# Out:
# Volume = 50939.17

# %% [markdown]
# # Q7. Count the  number of digits in a number. Example: 3454 has 4 digits.

# %% [markdown]
# ## #Taking following inputs one by one:
# ## #3454 output--> 4
# ## #675.998 output --> 6
# ## #6whdks output --> Please enter number only!

# %%
def has_digits(x):
    count = 0
    for i in number:
        if i.isdigit()==False: # check if it is a digit or not
            if i == ".": #let the function to count after decimal 
                count -=1 # decrease value by 1 to compensate for increase in count by 1 because of "."
                pass
            else:
                print("Please enter number only!")
                return
        count +=1
    return(count)

number = input("Please enter a number:")
ans = has_digits(number)
if ans != None:
    print("Number of digits=", ans)
# Out:
# Number of digits= 4

# %% [markdown]
# # Q8. Write a program that accepts a string and gives output string with all capital letters.

# %% [markdown]
# # #taking input --> Hello there, how are you!

# %%
s = input("Enter a string:")
print(s.upper())
# Out:
# HELLO THERE, HOW ARE YOU!

# %% [markdown]
# # Q9. Write a program to that accepts a string s, an index number n and a character ‘c’. And outputs the string replaced with the character at the index number n. Example- ‘hello’ , 0 , ‘j’ ==> ‘jello’.
# (Hint2: You can try it by join function too by typecasting it to list)

# %% [markdown]
# # #taking ‘hello’ , 0 , ‘j’ ==> ‘jello’

# %%
string, place, character = input().split()
if int(place) < string.__len__():
    string = list(string)
    string[int(place)] = character
    print("".join(string))
else:
    print("Index not exist!")
# Out:
# jello

# %% [markdown]
# # Q10. Reverse a string. Example: 'Hey there' = 'ereht yeH'

# %% [markdown]
# # #Taking Hey there

# %%
s = input("Enter a string")
print(s[::-1])
# Out:
# ereht yeH
